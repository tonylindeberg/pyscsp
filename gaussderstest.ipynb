# %%
import math
import numpy as np
import pyscsp.discscsp
import pyscsp.gaussders
from matplotlib import pyplot as plt
from importlib import reload

# %%
reload(pyscsp.discscsp)
reload(pyscsp.gaussders)
# Out:
# <module 'pyscsp.gaussders' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/gaussders.py'>

# %%
sum(pyscsp.gaussders.make1Dsamplgaussderfilter(1,1,10))
# Out:
# 2.7844332809221976e-18

# %%
sum(pyscsp.gaussders.make1Dintgaussderfilter(1,1,10))
# Out:
# 3.4509520177212505e-18

# %%
delta = pyscsp.discscsp.deltafcn(65,65)

# %%
samplgauss8_00 = pyscsp.gaussders.samplgaussderconv(delta, 0, 0, 8, 32)
plt.imshow(-samplgauss8_00, cmap='gray', interpolation='nearest')

# %%
samplgauss8_10 = pyscsp.gaussders.samplgaussderconv(delta, 1, 0, 8, 32)
plt.imshow(samplgauss8_10, cmap='gray', interpolation='nearest')

# %%
samplgauss8_01 = pyscsp.gaussders.samplgaussderconv(delta, 0, 1, 8, 32)
plt.imshow(samplgauss8_01, cmap='gray', interpolation='nearest')

# %%
samplgauss8_20 = pyscsp.gaussders.samplgaussderconv(delta, 2, 0, 8, 32)
plt.imshow(samplgauss8_20, cmap='gray', interpolation='nearest')

# %%
samplgauss8_11 = pyscsp.gaussders.samplgaussderconv(delta, 1, 1, 8, 32)
plt.imshow(samplgauss8_11, cmap='gray', interpolation='nearest')

# %%
samplgauss8_02 = pyscsp.gaussders.samplgaussderconv(delta, 0, 2, 8, 32)
plt.imshow(samplgauss8_02, cmap='gray', interpolation='nearest')

# %%
samplgauss8_30 = pyscsp.gaussders.samplgaussderconv(delta, 3, 0, 8, 32)
plt.imshow(samplgauss8_30, cmap='gray', interpolation='nearest')

# %%
samplgauss8_21 = pyscsp.gaussders.samplgaussderconv(delta, 2, 1, 8, 32)
plt.imshow(samplgauss8_21, cmap='gray', interpolation='nearest')

# %%
samplgauss8_12 = pyscsp.gaussders.samplgaussderconv(delta, 1, 2, 8, 32)
plt.imshow(samplgauss8_12, cmap='gray', interpolation='nearest')

# %%
samplgauss8_03 = pyscsp.gaussders.samplgaussderconv(delta, 0, 3, 8, 32)
plt.imshow(samplgauss8_03, cmap='gray', interpolation='nearest')

# %%
samplgauss8_40 = pyscsp.gaussders.samplgaussderconv(delta, 4, 0, 8, 32)
plt.imshow(samplgauss8_40, cmap='gray', interpolation='nearest')

# %%
samplgauss8_31 = pyscsp.gaussders.samplgaussderconv(delta, 3, 1, 8, 32)
plt.imshow(samplgauss8_31, cmap='gray', interpolation='nearest')

# %%
samplgauss8_22 = pyscsp.gaussders.samplgaussderconv(delta, 2, 2, 8, 32)
plt.imshow(samplgauss8_22, cmap='gray', interpolation='nearest')

# %%
samplgauss8_13 = pyscsp.gaussders.samplgaussderconv(delta, 1, 3, 8, 32)
plt.imshow(samplgauss8_13, cmap='gray', interpolation='nearest')

# %%
samplgauss8_04 = pyscsp.gaussders.samplgaussderconv(delta, 0, 4, 8, 32)
plt.imshow(samplgauss8_04, cmap='gray', interpolation='nearest')

# %%
intgauss8_00 = pyscsp.gaussders.intgaussderconv(delta, 0, 0, 8, 32)
plt.imshow(-intgauss8_00, cmap='gray', interpolation='nearest')

# %%
intgauss8_10 = pyscsp.gaussders.intgaussderconv(delta, 1, 0, 8, 32)
plt.imshow(intgauss8_10, cmap='gray', interpolation='nearest')

# %%
intgauss8_01 = pyscsp.gaussders.intgaussderconv(delta, 0, 1, 8, 32)
plt.imshow(intgauss8_01, cmap='gray', interpolation='nearest')

# %%
intgauss8_20 = pyscsp.gaussders.intgaussderconv(delta, 2, 0, 8, 32)
plt.imshow(intgauss8_20, cmap='gray', interpolation='nearest')

# %%
intgauss8_11 = pyscsp.gaussders.intgaussderconv(delta, 1, 1, 8, 32)
plt.imshow(intgauss8_11, cmap='gray', interpolation='nearest')

# %%
intgauss8_02 = pyscsp.gaussders.intgaussderconv(delta, 0, 2, 8, 32)
plt.imshow(intgauss8_02, cmap='gray', interpolation='nearest')

# %%
intgauss8_30 = pyscsp.gaussders.intgaussderconv(delta, 3, 0, 8, 32)
plt.imshow(intgauss8_30, cmap='gray', interpolation='nearest')

# %%
intgauss8_21 = pyscsp.gaussders.intgaussderconv(delta, 2, 1, 8, 32)
plt.imshow(intgauss8_21, cmap='gray', interpolation='nearest')

# %%
intgauss8_12 = pyscsp.gaussders.intgaussderconv(delta, 1, 2, 8, 32)
plt.imshow(intgauss8_12, cmap='gray', interpolation='nearest')

# %%
intgauss8_03 = pyscsp.gaussders.intgaussderconv(delta, 0, 3, 8, 32)
plt.imshow(intgauss8_03, cmap='gray', interpolation='nearest')

# %%
intgauss8_40 = pyscsp.gaussders.intgaussderconv(delta, 4, 0, 8, 32)
plt.imshow(intgauss8_40, cmap='gray', interpolation='nearest')

# %%
intgauss8_31 = pyscsp.gaussders.intgaussderconv(delta, 3, 1, 8, 32)
plt.imshow(intgauss8_31, cmap='gray', interpolation='nearest')

# %%
intgauss8_22 = pyscsp.gaussders.intgaussderconv(delta, 2, 2, 8, 32)
plt.imshow(intgauss8_22, cmap='gray', interpolation='nearest')

# %%
intgauss8_13 = pyscsp.gaussders.intgaussderconv(delta, 1, 3, 8, 32)
plt.imshow(intgauss8_13, cmap='gray', interpolation='nearest')

# %%
intgauss8_04 = pyscsp.gaussders.intgaussderconv(delta, 0, 4, 8, 32)
plt.imshow(intgauss8_04, cmap='gray', interpolation='nearest')

# %%
delta = pyscsp.discscsp.deltafcn(65,65)

# %%
reload(pyscsp.discscsp)
reload(pyscsp.gaussders)
# Out:
# <module 'pyscsp.gaussders' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/gaussders.py'>

# %%
pyscsp.gaussders.N_from_epsilon_2D(2, 8, 0.0001)
# Out:
# 38

# %%
samplgaussder8_00 = pyscsp.gaussders.gaussderconv(delta, 0, 0, 9, 'samplgaussdervar')
plt.imshow(-samplgaussder8_00, cmap='gray', interpolation='nearest')

# %%
samplgaussder8_10 = pyscsp.gaussders.gaussderconv(delta, 1, 0, 9, 'samplgaussdervar')
plt.imshow(samplgaussder8_10, cmap='gray', interpolation='nearest')

# %%
samplgaussder8_01 = pyscsp.gaussders.gaussderconv(delta, 0, 1, 9, 'samplgaussdervar')
plt.imshow(samplgaussder8_01, cmap='gray', interpolation='nearest')

# %%
samplgaussder8_20 = pyscsp.gaussders.gaussderconv(delta, 2, 0, 9, 'samplgaussdervar')
plt.imshow(samplgaussder8_20, cmap='gray', interpolation='nearest')

# %%
samplgaussder8_11 = pyscsp.gaussders.gaussderconv(delta, 1, 1, 9, 'samplgaussdervar')
plt.imshow(samplgaussder8_11, cmap='gray', interpolation='nearest')

# %%
samplgaussder8_02 = pyscsp.gaussders.gaussderconv(delta, 0, 2, 9, 'samplgaussdervar')
plt.imshow(samplgaussder8_02, cmap='gray', interpolation='nearest')

# %%
intgaussder8_00 = pyscsp.gaussders.gaussderconv(delta, 0, 0, 9, 'intgaussdervar')
plt.imshow(-intgaussder8_00, cmap='gray', interpolation='nearest')

# %%
intgaussder8_10 = pyscsp.gaussders.gaussderconv(delta, 1, 0, 9, 'intgaussdervar')
plt.imshow(intgaussder8_10, cmap='gray', interpolation='nearest')

# %%
intgaussder8_01 = pyscsp.gaussders.gaussderconv(delta, 0, 1, 9, 'intgaussdervar')
plt.imshow(intgaussder8_01, cmap='gray', interpolation='nearest')

# %%
intgaussder8_20 = pyscsp.gaussders.gaussderconv(delta, 2, 0, 9, 'intgaussdervar')
plt.imshow(intgaussder8_20, cmap='gray', interpolation='nearest')

# %%
intgaussder8_11 = pyscsp.gaussders.gaussderconv(delta, 1, 1, 9, 'intgaussdervar')
plt.imshow(intgaussder8_11, cmap='gray', interpolation='nearest')

# %%
intgaussder8_02 = pyscsp.gaussders.gaussderconv(delta, 0, 2, 9, 'intgaussdervar')
plt.imshow(intgaussder8_02, cmap='gray', interpolation='nearest')

# %%
reload(pyscsp.discscsp)
reload(pyscsp.gaussders)
# Out:
# <module 'pyscsp.gaussders' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/gaussders.py'>

# %%
L = pyscsp.gaussders.gaussderNjetfcn(delta, 'L', 8)
plt.imshow(-L, cmap='gray', interpolation='nearest')

# %%
Lx = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lx', 8)
plt.imshow(Lx, cmap='gray', interpolation='nearest')

# %%
Ly = pyscsp.gaussders.gaussderNjetfcn(delta, 'Ly', 8)
plt.imshow(Ly, cmap='gray', interpolation='nearest')

# %%
Lxx = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxx', 8)
plt.imshow(Lxx, cmap='gray', interpolation='nearest')

# %%
Lxy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxy', 8)
plt.imshow(Lxy, cmap='gray', interpolation='nearest')

# %%
Lyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lyy', 8)
plt.imshow(Lyy, cmap='gray', interpolation='nearest')

# %%
reload(pyscsp.discscsp)
reload(pyscsp.gaussders)
# Out:
# <module 'pyscsp.gaussders' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/gaussders.py'>

# %%
dala = pyscsp.discscsp.RGB2L(plt.imread('testimages/dalahast.jpg')/1)
plt.imshow(dala, cmap='gray', interpolation='nearest')

# %%
Lv = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lv', 4)
plt.imshow(-Lv, cmap='gray', interpolation='nearest')

# %%
Lv2 = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lv2', 4)
plt.imshow(-Lv2, cmap='gray', interpolation='nearest')

# %%
Laplace = pyscsp.gaussders.gaussderNjetfcn(dala, 'Laplace', 4)
plt.imshow(Laplace, cmap='gray', interpolation='nearest')

# %%
detHessian = pyscsp.gaussders.gaussderNjetfcn(dala, 'detHessian', 4)
plt.imshow(detHessian, cmap='gray', interpolation='nearest')

# %%
sqrtdetHessian = pyscsp.gaussders.gaussderNjetfcn(dala, 'sqrtdetHessian', 4)
plt.imshow(sqrtdetHessian, cmap='gray', interpolation='nearest')

# %%
Kappa = pyscsp.gaussders.gaussderNjetfcn(dala, 'Kappa', 4)
plt.imshow(Kappa, cmap='gray', interpolation='nearest')

# %%
Lv2Lvv = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lv2Lvv', 4)
plt.imshow(Lv2Lvv < 0, cmap='gray', interpolation='nearest')

# %%
Lv3Lvvv = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lv3Lvvv', 4)
plt.imshow(Lv3Lvvv < 0, cmap='gray', interpolation='nearest')

# %%
Lp = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lp', 4)
plt.imshow(Lp, cmap='gray', interpolation='nearest')

# %%
Lq = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lq', 4)
plt.imshow(Lq, cmap='gray', interpolation='nearest')

# %%
Lpp = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lpp', 8)
plt.imshow(Lpp, cmap='gray', interpolation='nearest')

# %%
Lqq = pyscsp.gaussders.gaussderNjetfcn(dala, 'Lqq', 8)
plt.imshow(Lqq, cmap='gray', interpolation='nearest')

# %%
reload(pyscsp.discscsp)
reload(pyscsp.gaussders)
# Out:
# <module 'pyscsp.gaussders' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/gaussders.py'>

# %%
Lxxx = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxxx', 8)
plt.imshow(Lxxx, cmap='gray', interpolation='nearest')

# %%
Lxxy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxxy', 8)
plt.imshow(Lxxy, cmap='gray', interpolation='nearest')

# %%
Lxyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxyy', 8)
plt.imshow(Lxyy, cmap='gray', interpolation='nearest')

# %%
Lyyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lyyy', 8)
plt.imshow(Lyyy, cmap='gray', interpolation='nearest')

# %%
Lxxxx = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxxxx', 8)
plt.imshow(Lxxxx, cmap='gray', interpolation='nearest')

# %%
Lxxxy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxxxy', 8)
plt.imshow(Lxxxy, cmap='gray', interpolation='nearest')

# %%
Lxxyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxxyy', 8)
plt.imshow(Lxxyy, cmap='gray', interpolation='nearest')

# %%
Lxyyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lxyyy', 8)
plt.imshow(Lxyyy, cmap='gray', interpolation='nearest')

# %%
Lyyyy = pyscsp.gaussders.gaussderNjetfcn(delta, 'Lyyyy', 8)
plt.imshow(Lyyyy, cmap='gray', interpolation='nearest')
