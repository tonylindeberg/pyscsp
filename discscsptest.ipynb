# %%
import numpy as np
import pyscsp.discscsp as discscsp
from matplotlib import pyplot as plt
from importlib import reload

# %%
reload(discscsp)
# Out:
# <module 'pyscsp.discscsp' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/discscsp.py'>

# %%
discscsp.truncerrtransf(0.001,2)
# Out:
# 0.0005001250625390474

# %%
print(discscsp.make1Ddiscgaussfilter(1))
# Out:
# [3.66430880e-08 5.88319509e-07 8.27311622e-06 9.98657141e-05
#  1.00693026e-03 8.15530777e-03 4.99387769e-02 2.07910415e-01
#  4.65759608e-01 2.07910415e-01 4.99387769e-02 8.15530777e-03
#  1.00693026e-03 9.98657141e-05 8.27311622e-06 5.88319509e-07
#  3.66430880e-08]

# %%
sum(discscsp.make1Ddiscgaussfilter(1))
# Out:
# 0.9999999957276609

# %%
print(discscsp.deltafcn(3,3))
# Out:
# [[0. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 0.]]

# %%
delta = discscsp.deltafcn(65,65)

# %%
gauss8 = discscsp.discgaussconv(delta,8)

# %%
sum(sum(gauss8))
# Out:
# 0.999999994598538

# %%
plt.imshow(-gauss8, cmap='gray', interpolation='nearest')

# %%
print(discscsp.dxmask())
# Out:
# [[-0.5  0.   0.5]]

# %%
print(discscsp.dymask())
# Out:
# [[ 0.5]
#  [ 0. ]
#  [-0.5]]

# %%
print(discscsp.dxxmask())
# Out:
# [[ 1 -2  1]]

# %%
print(discscsp.dxymask())
# Out:
# [[-0.25  0.    0.25]
#  [ 0.    0.    0.  ]
#  [ 0.25  0.   -0.25]]

# %%
print(discscsp.dyymask())
# Out:
# [[ 1]
#  [-2]
#  [ 1]]

# %%
Lx = discscsp.applyNjetfcn(gauss8, 'Lx')

# %%
plt.imshow(Lx, cmap='gray', interpolation='nearest')

# %%
Ly = discscsp.applyNjetfcn(gauss8, 'Ly')

# %%
plt.imshow(Ly, cmap='gray', interpolation='nearest')

# %%
Lxx = discscsp.applyNjetfcn(gauss8, 'Lxx')

# %%
plt.imshow(Lxx, cmap='gray', interpolation='nearest')

# %%
Lxy = discscsp.applyNjetfcn(gauss8, 'Lxy')

# %%
plt.imshow(Lxy, cmap='gray', interpolation='nearest')

# %%
Lyy = discscsp.applyNjetfcn(gauss8, 'Lyy')

# %%
plt.imshow(Lyy, cmap='gray', interpolation='nearest')

# %%
Lxxx = discscsp.applyNjetfcn(gauss8, 'Lxxx')

# %%
plt.imshow(Lxxx, cmap='gray', interpolation='nearest')

# %%
Lxxy = discscsp.applyNjetfcn(gauss8, 'Lxxy')

# %%
plt.imshow(Lxxy, cmap='gray', interpolation='nearest')

# %%
Lxyy = discscsp.applyNjetfcn(gauss8, 'Lxyy')

# %%
plt.imshow(Lxyy, cmap='gray', interpolation='nearest')

# %%
Lyyy = discscsp.applyNjetfcn(gauss8, 'Lyyy')

# %%
plt.imshow(Lyyy, cmap='gray', interpolation='nearest')

# %%
Lxxxx = discscsp.applyNjetfcn(gauss8, 'Lxxxx')

# %%
plt.imshow(Lxxxx, cmap='gray', interpolation='nearest')

# %%
Lxxxy = discscsp.applyNjetfcn(gauss8, 'Lxxxy')

# %%
plt.imshow(Lxxxy, cmap='gray', interpolation='nearest')

# %%
Lxxyy = discscsp.applyNjetfcn(gauss8, 'Lxxyy')

# %%
plt.imshow(Lxxyy, cmap='gray', interpolation='nearest')

# %%
Lxyyy = discscsp.applyNjetfcn(gauss8, 'Lxyyy')

# %%
plt.imshow(Lxyyy, cmap='gray', interpolation='nearest')

# %%
Lyyyy = discscsp.applyNjetfcn(gauss8, 'Lyyyy')

# %%
plt.imshow(Lyyyy, cmap='gray', interpolation='nearest')

# %%
Laplace = discscsp.applyNjetfcn(gauss8, 'Laplace')

# %%
plt.imshow(Laplace, cmap='gray', interpolation='nearest')

# %%
detHessian = discscsp.applyNjetfcn(gauss8, 'detHessian')

# %%
plt.imshow(detHessian, cmap='gray', interpolation='nearest')

# %%
Lv = discscsp.applyNjetfcn(gauss8, 'Lv')

# %%
plt.imshow(Lv, cmap='gray', interpolation='nearest')

# %%
Laplace = discscsp.computeNjetfcn(delta, 'Laplace', 8)

# %%
plt.imshow(Laplace, cmap='gray', interpolation='nearest')

# %%
sqrtdetHessian = discscsp.computeNjetfcn(delta, 'sqrtdetHessian', 8)

# %%
plt.imshow(sqrtdetHessian, cmap='gray', interpolation='nearest')

# %%
Lv2Lvv = discscsp.computeNjetfcn(delta, 'Lv2Lvv', 8)

# %%
plt.imshow(Lv2Lvv, cmap='gray', interpolation='nearest')

# %%
Lv3Lvvv = discscsp.computeNjetfcn(delta, 'Lv3Lvvv', 8)

# %%
plt.imshow(Lv3Lvvv, cmap='gray', interpolation='nearest')

# %%
Lp = discscsp.computeNjetfcn(delta, 'Lp', 8)

# %%
plt.imshow(Lp, cmap='gray', interpolation='nearest')

# %%
Lq = discscsp.computeNjetfcn(delta, 'Lq', 8)

# %%
plt.imshow(Lq, cmap='gray', interpolation='nearest')

# %%
Lpp = discscsp.computeNjetfcn(delta, 'Lpp', 8)

# %%
plt.imshow(Lpp, cmap='gray', interpolation='nearest')

# %%
Lqq = discscsp.computeNjetfcn(delta, 'Lqq', 8)

# %%
plt.imshow(Lqq, cmap='gray', interpolation='nearest')

# %%
print(discscsp.scspnormdermethodobject())
# Out:
# ScSpNormDerMethod(scspmethod=ScSpMethod(methodname='discgauss', epsilon=1e-08), normdermethod='Lpnorm', gamma=1.0)

# %%
print(discscsp.defaultscspnormdermethodobject('discgaussLp'))
# Out:
# ScSpNormDerMethod(scspmethod=ScSpMethod(methodname='discgauss', epsilon=1e-08), normdermethod='Lpnorm', gamma=1.0)

# %%
from math import sqrt

# %%
discscsp.normderfactor(1, 1, sqrt(2), 'discgaussLp')
# Out:
# 2.3205257721519477

# %%
print(discscsp.dymask())
# Out:
# [[ 0.5]
#  [ 0. ]
#  [-0.5]]

# %%
print(discscsp.dxxymask())
# Out:
# [[ 0.5 -1.   0.5]
#  [ 0.   0.   0. ]
#  [-0.5  1.  -0.5]]

# %%
print(discscsp.dxyymask())
# Out:
# [[-0.5  0.   0.5]
#  [ 1.   0.  -1. ]
#  [-0.5  0.   0.5]]

# %%
print(discscsp.dxxxymask())
# Out:
# [[-0.25  0.5   0.   -0.5   0.25]
#  [ 0.    0.    0.    0.    0.  ]
#  [ 0.25 -0.5   0.    0.5  -0.25]]

# %%
print(discscsp.dxymask())
# Out:
# [[-0.25  0.    0.25]
#  [ 0.    0.    0.  ]
#  [ 0.25  0.   -0.25]]

# %%
delta = discscsp.deltafcn(255,255)

# %%
discscsp.filtermean(delta)
# Out:
# (0.0, 0.0)

# %%
discscsp.variance(delta)
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
discscsp.filtermean(discscsp.deltafcn(256,256))
# Out:
# (0.0, 0.0)

# %%
discscsp.variance(discscsp.deltafcn(256,256))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
discscsp.variance(discscsp.computeNjetfcn(delta, 'L', 1))
# Out:
# array([[0.99999965, 0.        ],
#        [0.        , 0.99999965]])

# %%
discscsp.variance(discscsp.computeNjetfcn(delta, 'L', 2))
# Out:
# array([[ 3.99999970e+00, -5.55111514e-17],
#        [-5.55111514e-17,  3.99999970e+00]])

# %%
discscsp.variance(discscsp.computeNjetfcn(delta, 'L', 4))
# Out:
# array([[ 1.59999985e+01, -8.32667272e-17],
#        [-8.32667272e-17,  1.59999985e+01]])

# %%
discscsp.variance(discscsp.computeNjetfcn(delta, 'L', 8))
# Out:
# array([[ 6.39999934e+01, -1.81015865e-16],
#        [-1.81015865e-16,  6.39999934e+01]])

# %%
discscsp.variance(discscsp.computeNjetfcn(delta, 'L', 16))
# Out:
# array([[ 2.55999962e+02, -1.72326536e-15],
#        [-1.72326536e-15,  2.55999962e+02]])

# %%
dala = plt.imread('testimages/dalahast.jpg')

# %%
plt.imshow(dala)

# %%
smoothpic = discscsp.scspconv(dala, 4)

# %%
plt.imshow(smoothpic/255)

# %%
funcpic = discscsp.computeNjetfcn(dala, 'L', 4)

# %%
plt.imshow(funcpic/255)

# %%
funcpic = discscsp.computeNjetfcn(discscsp.RGB2L(dala), 'Laplace', 4)

# %%
plt.imshow(funcpic/(255), cmap='gray', interpolation='nearest')

# %%
funcpic = discscsp.computeNjetfcn(discscsp.RGB2L(dala), 'Lx', 4)

# %%
plt.imshow(funcpic/(255), cmap='gray', interpolation='nearest')

# %%
delta = discscsp.deltafcn(255,255)

# %%
bigdelta = discscsp.deltafcn(1023,1023)

# %%
sampl1 = discscsp.samplgaussconv(delta, 1)

# %%
plt.imshow(-sampl1, cmap='gray', interpolation='nearest')

# %%
sampl16 = discscsp.samplgaussconv(delta, 16)

# %%
plt.imshow(-sampl16, cmap='gray', interpolation='nearest')

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 1))
# Out:
# array([[9.99999789e-01, 7.70371961e-34],
#        [7.70371961e-34, 9.99999789e-01]])

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 4))
# Out:
# array([[1.60000000e+01, 2.77555756e-17],
#        [2.77555756e-17, 1.60000000e+01]])

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 16))
# Out:
# array([[ 2.55999999e+02, -3.21006867e-16],
#        [-3.21006867e-16,  2.55999999e+02]])

# %%
normsampl1 = discscsp.normsamplgaussconv(delta, 1)

# %%
plt.imshow(-normsampl1, cmap='gray', interpolation='nearest')

# %%
normsampl16 = discscsp.normsamplgaussconv(delta, 16)

# %%
plt.imshow(-normsampl16, cmap='gray', interpolation='nearest')

# %%
int1 = discscsp.intgaussconv(delta, 1)

# %%
plt.imshow(-int1, cmap='gray', interpolation='nearest')

# %%
int16 = discscsp.intgaussconv(delta, 16)

# %%
plt.imshow(-int16, cmap='gray', interpolation='nearest')

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 1))
# Out:
# array([[9.99999789e-01, 7.70371961e-34],
#        [7.70371961e-34, 9.99999789e-01]])

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 4))
# Out:
# array([[1.60000000e+01, 2.77555756e-17],
#        [2.77555756e-17, 1.60000000e+01]])

# %%
discscsp.variance(discscsp.samplgaussconv(delta, 16))
# Out:
# array([[ 2.55999999e+02, -3.21006867e-16],
#        [-3.21006867e-16,  2.55999999e+02]])

# %%
discscsp.variance(discscsp.normsamplgaussconv(delta, 1))
# Out:
# array([[9.99999789e-01, 1.38777878e-17],
#        [1.38777878e-17, 9.99999789e-01]])

# %%
discscsp.variance(discscsp.normsamplgaussconv(delta, 4))
# Out:
# array([[1.60000000e+01, 5.55111512e-17],
#        [5.55111512e-17, 1.60000000e+01]])

# %%
discscsp.variance(discscsp.normsamplgaussconv(delta, 16))
# Out:
# array([[2.55999999e+02, 6.12293427e-16],
#        [6.12293427e-16, 2.55999999e+02]])

# %%
discscsp.variance(discscsp.intgaussconv(delta, 1))
# Out:
# array([[ 1.08333332e+00, -2.77555756e-17],
#        [-2.77555756e-17,  1.08333332e+00]])

# %%
discscsp.variance(discscsp.intgaussconv(delta, 4))
# Out:
# array([[ 1.60833333e+01, -2.77555756e-17],
#        [-2.77555756e-17,  1.60833333e+01]])

# %%
discscsp.variance(discscsp.intgaussconv(delta, 16))
# Out:
# array([[2.56083332e+02, 3.24735953e-16],
#        [3.24735953e-16, 2.56083332e+02]])

# %%
discscsp.variance(discscsp.intgaussconv(bigdelta, 64))
# Out:
# array([[ 4.09608331e+03, -4.82776144e-15],
#        [-4.82776144e-15,  4.09608331e+03]])

# %%
discscsp.filtermean(discscsp.intgaussconv(delta, 1))
# Out:
# (1.3877787807816232e-17, 0.0)

# %%
discscsp.filtermean(discscsp.intgaussconv(delta, 16))
# Out:
# (-1.5068111144102354e-16, 3.8986994275909664e-17)

# %%
sum(discscsp.make1Dintgaussfilter(16))
# Out:
# 0.9999999997757614

# %%
sum(discscsp.make1Dsamplgaussfilter(1))
# Out:
# 1.0000000053505658

# %%
sum(discscsp.make1Dnormsamplgaussfilter(1))
# Out:
# 1.0000000000000002

# %%
sum(discscsp.make1Ddiscgaussfilter(16))
# Out:
# 0.9999999913067791

# %%
discscsp.make1Dintgaussfilter(1)
# Out:
# array([4.01280675e-11, 1.89494025e-08, 3.37868356e-06, 2.29231406e-04,
#        5.97703625e-03, 6.05975359e-02, 2.41730337e-01, 3.82924923e-01,
#        2.41730337e-01, 6.05975359e-02, 5.97703625e-03, 2.29231406e-04,
#        3.37868356e-06, 1.89494025e-08, 4.01280120e-11])

# %%
discscsp.make1Dsamplgaussfilter(1)
# Out:
# array([9.13472041e-12, 6.07588285e-09, 1.48671951e-06, 1.33830226e-04,
#        4.43184841e-03, 5.39909665e-02, 2.41970725e-01, 3.98942280e-01,
#        2.41970725e-01, 5.39909665e-02, 4.43184841e-03, 1.33830226e-04,
#        1.48671951e-06, 6.07588285e-09, 9.13472041e-12])

# %%
discscsp.make1Dnormsamplgaussfilter(1)
# Out:
# array([9.13472036e-12, 6.07588282e-09, 1.48671951e-06, 1.33830225e-04,
#        4.43184839e-03, 5.39909662e-02, 2.41970723e-01, 3.98942278e-01,
#        2.41970723e-01, 5.39909662e-02, 4.43184839e-03, 1.33830225e-04,
#        1.48671951e-06, 6.07588282e-09, 9.13472036e-12])

# %%
discscsp.make1Ddiscgaussfilter(1)
# Out:
# array([3.66430880e-08, 5.88319509e-07, 8.27311622e-06, 9.98657141e-05,
#        1.00693026e-03, 8.15530777e-03, 4.99387769e-02, 2.07910415e-01,
#        4.65759608e-01, 2.07910415e-01, 4.99387769e-02, 8.15530777e-03,
#        1.00693026e-03, 9.98657141e-05, 8.27311622e-06, 5.88319509e-07,
#        3.66430880e-08])

# %%
funcpic = discscsp.computeNjetfcn(discscsp.RGB2L(dala), 'Laplace', 4, normdermethod='intgaussLp')

# %%
plt.imshow(funcpic, cmap='gray', interpolation='nearest')

# %%
linint1 = discscsp.linintgaussconv(delta, 1)

# %%
plt.imshow(-linint1, cmap='gray', interpolation='nearest')

# %%
linint16 = discscsp.linintgaussconv(delta, 16)

# %%
plt.imshow(-linint16, cmap='gray', interpolation='nearest')

# %%
plt.plot(discscsp.make1Dlinintgaussfilter(16))

# %%
sum(discscsp.make1Dlinintgaussfilter(1))
# Out:
# 0.9999999999996482

# %%
sum(discscsp.make1Dlinintgaussfilter(16))
# Out:
# 0.9999999997742527

# %%
sum(discscsp.make1Dlinintgaussfilter(64))
# Out:
# 0.999999999738927

# %%
discscsp.variance(discscsp.linintgaussconv(delta, 1))
# Out:
# array([[1.16666667e+00, 1.38777878e-17],
#        [1.38777878e-17, 1.16666667e+00]])

# %%
discscsp.variance(discscsp.linintgaussconv(delta, 16))
# Out:
# array([[ 2.56166666e+02, -1.94870268e-15],
#        [-1.94870268e-15,  2.56166666e+02]])

# %%
discscsp.variance(discscsp.linintgaussconv(bigdelta, 64))
# Out:
# array([[ 4.09616665e+03, -5.53837219e-15],
#        [-5.53837219e-15,  4.09616665e+03]])

# %%
1/6
# Out:
# 0.16666666666666666

# %%
1/12
# Out:
# 0.08333333333333333

# %%
discscsp.variance(discscsp.samplgaussconv(discscsp.samplgaussconv(delta, 16), 16))
# Out:
# array([[5.11999964e+02, 5.84283327e-17],
#        [5.84283327e-17, 5.11999964e+02]])

# %%
discscsp.variance(discscsp.samplgaussconv(discscsp.normsamplgaussconv(delta, 16), 16))
# Out:
# array([[5.11999964e+02, 4.86318885e-16],
#        [4.86318885e-16, 5.11999964e+02]])

# %%
discscsp.variance(discscsp.intgaussconv(discscsp.intgaussconv(delta, 16), 16))
# Out:
# array([[5.1216663e+02, 8.5315869e-16],
#        [8.5315869e-16, 5.1216663e+02]])

# %%
discscsp.variance(discscsp.linintgaussconv(discscsp.linintgaussconv(delta, 16), 16))
# Out:
# array([[ 5.12333297e+02, -6.96615143e-16],
#        [-6.96615143e-16,  5.12333297e+02]])

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.discgaussconv(discscsp.deltafcn(9,9),1.0), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.scspconv(discscsp.deltafcn(9,9),0.3,scspmethod='intgauss'), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.scspconv(discscsp.deltafcn(9,9),1.0,'intgauss'), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.scspconv(discscsp.deltafcn(9,9),0.3,'intgauss'), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.scspconv(discscsp.deltafcn(9,9),1.0,'samplgauss'), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
plt.imshow(discscsp.applyNjetfcn(discscsp.scspconv(discscsp.deltafcn(9,9),0.3,'samplgauss'), 'Lxx'), cmap='gray', interpolation='nearest')

# %%
print(discscsp.scaleoffset_variance('discgauss'))
# Out:
# 0.0

# %%
print(discscsp.scaleoffset_variance('samplgauss'))
# Out:
# 0.0

# %%
print(discscsp.scaleoffset_variance('normsamplgauss'))
# Out:
# 0.0

# %%
print(discscsp.scaleoffset_variance('intgauss'))
# Out:
# 0.08333333333333333

# %%
print(discscsp.scaleoffset_variance('linintgauss'))
# Out:
# 0.16666666666666666

# %%
tmp = discscsp.RGB2LUV(plt.imread('testimages/dalahast.jpg'))

# %%
testsignal = discscsp.make1Ddiscgaussfilter(1)
print(testsignal)
# Out:
# [3.66430880e-08 5.88319509e-07 8.27311622e-06 9.98657141e-05
#  1.00693026e-03 8.15530777e-03 4.99387769e-02 2.07910415e-01
#  4.65759608e-01 2.07910415e-01 4.99387769e-02 8.15530777e-03
#  1.00693026e-03 9.98657141e-05 8.27311622e-06 5.88319509e-07
#  3.66430880e-08]

# %%
tmp1 = discscsp.scspconv(testsignal, 1)
print(tmp1)
# Out:
# [4.15789978e-06 3.04412872e-05 2.16563317e-04 1.32976135e-03
#  6.86536540e-03 2.87912226e-02 9.32390333e-02 2.15269289e-01
#  3.08508323e-01 2.15269289e-01 9.32390333e-02 2.87912226e-02
#  6.86536540e-03 1.32976135e-03 2.16563317e-04 3.04412872e-05
#  4.15789978e-06]

# %%
tmp2 = discscsp.scspconv_mult(testsignal, [1, 2])
print(tmp2)
print(discscsp.variance1D(tmp2[0, :]))
print(discscsp.variance1D(tmp2[1, :]))
# Out:
# [[4.15789978e-06 3.04412872e-05 2.16563317e-04 1.32976135e-03
#   6.86536540e-03 2.87912226e-02 9.32390333e-02 2.15269289e-01
#   3.08508323e-01 2.15269289e-01 9.32390333e-02 2.87912226e-02
#   6.86536540e-03 1.32976135e-03 2.16563317e-04 3.04412872e-05
#   4.15789978e-06]
#  [6.29540586e-04 1.75906768e-03 5.34508580e-03 1.45416627e-02
#   3.44192647e-02 6.96107852e-02 1.17951913e-01 1.63972268e-01
#   1.83540813e-01 1.63972268e-01 1.17951913e-01 6.96107852e-02
#   3.44192647e-02 1.45416627e-02 5.34508580e-03 1.75906768e-03
#   6.29540586e-04]]
# 1.9999806460769491
# 4.990869642225547

# %%
reload(discscsp)
# Out:
# <module 'pyscsp.discscsp' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/discscsp.py'>

# %%
delta32 = discscsp.deltafcn(32, 32)
tmp3 = discscsp.scspconv_mult(delta32, [1, 2, 4])
print(discscsp.variance(tmp3[0, :, :]))
print(discscsp.variance(tmp3[1, :, :]))
print(discscsp.variance(tmp3[2, :, :]))
# Out:
# [[9.99999654e-01 1.38777879e-17]
#  [1.38777879e-17 9.99999654e-01]]
# [[3.99999896e+00 8.28503160e-18]
#  [8.28503160e-18 3.99999896e+00]]
# [[1.59924648e+01 9.75991397e-18]
#  [9.75991397e-18 1.59924648e+01]]

# %%
dala = plt.imread('testimages/dalahast.jpg')
print(discscsp.scspconv_mult(dala, [1, 2, 4]))
# Out:
# [[[[165.59589244 173.47109003 176.14420773]
#    [165.83357812 171.7778364  174.90088344]
#    [165.47119488 170.45523841 173.5195919 ]
#    ...
#    [170.2679999  176.88462169 180.78693903]
#    [172.23780603 178.02490222 181.85750087]
#    [173.31912845 179.12590062 182.87329972]]
#
#   [[165.60325876 172.92223996 175.63290411]
#    [165.42230822 171.16576627 174.14295399]
#    [165.23769638 170.20452304 173.1710487 ]
#    ...
#    [169.36912479 176.64155477 180.0830543 ]
#    [170.65590219 177.25130837 180.75824656]
#    [171.59105692 178.43264155 181.82501026]]
#
#   [[165.48135598 172.55253313 175.03053505]
#    [164.91203068 170.62056925 173.42514524]
#    [164.79187656 169.88083606 172.76417301]
#    ...
#    [169.7154006  176.92227609 180.24680693]
#    [169.46342688 176.68417042 179.9541774 ]
#    [169.9073482  177.35867563 180.54306106]]
#
#   ...
#
#   [[135.60799515  64.75912885  14.7225134 ]
#    [135.7567405   64.8700427   14.14344133]
#    [135.47865568  64.85085494  13.09037947]
#    ...
#    [153.17348534 134.65854195 107.66892948]
#    [153.82380878 134.4394797  107.35570132]
#    [154.46100015 134.66431856 107.58794677]]
#
#   [[134.56048156  64.66812059  14.26558319]
#    [134.47548694  64.31038178  13.79298015]
#    [133.74864757  63.46711014  12.97419005]
#    ...
#    [152.66036219 133.26327811 105.89247413]
#    [153.248977   133.60700026 105.6335083 ]
#    [153.80725152 134.04932134 105.8321604 ]]
#
#   [[130.00360257  60.84415198  11.21023206]
#    [130.07742254  60.25163788  10.72751991]
#    [129.68790962  59.22341471  10.2717712 ]
#    ...
#    [152.42641023 132.42202054 105.2107043 ]
#    [152.90960063 132.65235502 105.09452893]
#    [153.25443499 132.87846649 105.17552747]]]
#
#
#  [[[165.32511355 171.83779198 174.62159616]
#    [165.18934934 171.51922524 174.30198144]
#    [164.93794509 171.19040656 173.91490423]
#    ...
#    [170.67775682 177.63754655 181.51926886]
#    [170.92378468 177.65569243 181.36416749]
#    [171.17050179 177.76972299 181.39804346]]
#
#   [[165.19814187 171.70872032 174.43878271]
#    [165.06768683 171.4206963  174.14961879]
#    [164.84343822 171.14846227 173.82116582]
#    ...
#    [170.56202011 177.46236754 181.28062311]
#    [170.71165506 177.46105149 181.11589944]
#    [170.88818787 177.55128662 181.12980992]]
#
#   [[164.9585661  171.53581088 174.17089783]
#    [164.84456197 171.30316016 173.93694118]
#    [164.67646422 171.12586409 173.70856518]
#    ...
#    [170.43595562 177.16186776 180.92732241]
#    [170.48295233 177.1603567  180.77731048]
#    [170.57650935 177.23086468 180.77646501]]
#
#   ...
#
#   [[133.24097836  62.23777715  12.65402909]
#    [133.15179497  62.1744155   12.41954325]
#    [133.01097233  62.07695828  12.09750914]
#    ...
#    [153.51143972 133.99485015 107.22921036]
#    [153.59857954 133.9386097  107.10363599]
#    [153.67938517 133.90251231 107.0357929 ]]
#
#   [[132.88726114  62.37561666  12.61012002]
#    [132.78121872  62.22824353  12.41470498]
#    [132.60221307  61.99932677  12.15705722]
#    ...
#    [153.20823415 133.60552158 106.5823485 ]
#    [153.35839378 133.64395503 106.49633017]
#    [153.47481864 133.66644197 106.44796962]]
#
#   [[132.41087399  62.17972121  12.39524697]
#    [132.30059593  61.97487175  12.23178756]
#    [132.11499602  61.65767274  12.02837379]
#    ...
#    [153.01435975 133.29681626 106.13437887]
#    [153.19353023 133.39018924 106.07570793]
#    [153.32478096 133.44666321 106.04147853]]]
#
#
#  [[[164.55993053 171.44548158 173.93651975]
#    [164.53166173 171.44136839 173.91921087]
#    [164.47902355 171.43401074 173.88793899]
#    ...
#    [170.84516763 177.60850865 181.6374333 ]
#    [170.78814958 177.52388911 181.50338232]
#    [170.75936875 177.4809481  181.43274992]]
#
#   [[164.53150238 171.45354155 173.93578267]
#    [164.50486098 171.44919675 173.91884258]
#    [164.4551654  171.44124907 173.88810295]
#    ...
#    [170.83781176 177.59703069 181.62926573]
#    [170.77773148 177.50959967 181.49384812]
#    [170.74735553 177.46523409 181.42255409]]
#
#   [[164.47721195 171.46595979 173.9333753 ]
#    [164.45340869 171.46086091 173.91679996]
#    [164.40884737 171.45122021 173.88645819]
#    ...
#    [170.82455778 177.58045466 181.62015926]
#    [170.75808947 177.48722588 181.48153362]
#    [170.72436702 177.43988406 181.40863695]]
#
#   ...
#
#   [[132.88291012  61.64403249  11.80627229]
#    [132.89834787  61.64868482  11.79111769]
#    [132.93259289  61.66084287  11.7657509 ]
#    ...
#    [153.58925237 133.8965353  107.35164727]
#    [153.61054107 133.91146228 107.34591912]
#    [153.62132317 133.91910086 107.34172442]]
#
#   [[132.82238947  61.6773417   11.86807939]
#    [132.8382167   61.68165709  11.85308853]
#    [132.87356037  61.69333581  11.82801036]
#    ...
#    [153.51683157 133.81217242 107.20744643]
#    [153.54262958 133.8316722  107.20311476]
#    [153.55567397 133.84155493 107.1994197 ]]
#
#   [[132.79303459  61.69987202  11.90317475]
#    [132.80907076  61.70395261  11.88830438]
#    [132.84500631  61.71527451  11.86343264]
#    ...
#    [153.4765908  133.76685375 107.12954747]
#    [153.50493134 133.78897386 107.12613217]
#    [153.51925831 133.8001485  107.12279086]]]]
