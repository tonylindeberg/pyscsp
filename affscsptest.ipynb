# %%
import math
import numpy as np
import pyscsp
import pyscsp.discscsp as discscsp
import pyscsp.affscsp as affscsp
from matplotlib import pyplot as plt
from importlib import reload

# %%
reload(pyscsp.discscsp)
reload(pyscsp.affscsp)
# Out:
# <module 'pyscsp.affscsp' from '/Users/tony/Work/GitHub.com-mirror/pyscsp/pyscsp/affscsp.py'>

# %%
affscsp.CxxCxyCyyfromlambda12phi(2, 1, 0)
# Out:
# (2.0, 0.0, 1.0)

# %%
affscsp.CxxCxyCyyfromlambda12phi(2, 1, math.pi/4)
# Out:
# (1.5, 0.5, 1.5)

# %%
affscsp.CxxCxyCyyfromsigma12phi(math.sqrt(2), 1, 0)
# Out:
# (2.0000000000000004, 0.0, 1.0)

# %%
affscsp.CxxCxyCyyfromsigma12phi(math.sqrt(2), 1, math.pi/4)
# Out:
# (1.5000000000000004, 0.5000000000000002, 1.5)

# %%
gauss84_0 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, 0, 0, 0, 64)
plt.imshow(-gauss84_0, cmap='gray', interpolation='nearest')

# %%
gauss84_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 0, 0, 32)
plt.imshow(-gauss84_30, cmap='gray', interpolation='nearest')

# %%
gauss84phi_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 1, 0, 32)
plt.imshow(gauss84phi_30, cmap='gray', interpolation='nearest')

# %%
gauss84phiphi_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 2, 0, 32)
plt.imshow(gauss84phiphi_30, cmap='gray', interpolation='nearest')

# %%
gauss84orth_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 0, 1, 32)
plt.imshow(gauss84orth_30, cmap='gray', interpolation='nearest')

# %%
gauss84orthorth_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 0, 2, 32)
plt.imshow(gauss84orthorth_30, cmap='gray', interpolation='nearest')

# %%
# ==>> The following use case does not work ...
# gauss84phiorth_30 = affscsp.sampldirderaffgausskernelfromsigma12phi(8, 4, math.pi/6, 1, 1, 32)
# plt.imshow(gauss84phiorth_30, cmap='gray', interpolation='nearest')

# %%
gauss84phi_30 = affscsp.numdirdersamplaffgausskernel(8, 4, math.pi/6, 1, 0, 32)
plt.imshow(gauss84phi_30, cmap='gray', interpolation='nearest')

# %%
gauss84phiphi_30 = affscsp.numdirdersamplaffgausskernel(8, 4, math.pi/6, 2, 0, 32)
plt.imshow(gauss84phiphi_30, cmap='gray', interpolation='nearest')

# %%
gauss84orth_30 = affscsp.numdirdersamplaffgausskernel(8, 4, math.pi/6, 0, 1, 32)
plt.imshow(gauss84orth_30, cmap='gray', interpolation='nearest')

# %%
gauss84orthorth_30 = affscsp.numdirdersamplaffgausskernel(8, 4, math.pi/6, 0, 2, 32)
plt.imshow(gauss84orthorth_30, cmap='gray', interpolation='nearest')

# %%
gauss84phiorth_30 = affscsp.numdirdersamplaffgausskernel(8, 4, math.pi/6, 1, 1, 32)
plt.imshow(gauss84phiorth_30, cmap='gray', interpolation='nearest')

# %%
gauss84phi_30 = affscsp.scnormnumdirdersamplaffgausskernel(8, 4, math.pi/6, 1, 0, 32)
plt.imshow(gauss84phi_30, cmap='gray', interpolation='nearest')

# %%
gauss84phi_30 = affscsp.L1normnumdirdersamplaffgausskernel(8, 4, math.pi/6, 1, 0, 32)
plt.imshow(gauss84phi_30, cmap='gray', interpolation='nearest')

# %%
np.sum(np.abs(gauss84phi_30))
# Out:
# 0.9983572917506353

# %%
gauss84phiphi_30 = affscsp.L1normnumdirdersamplaffgausskernel(8, 4, math.pi/6, 2, 0, 32)
plt.imshow(gauss84phiphi_30, cmap='gray', interpolation='nearest')

# %%
np.sum(np.abs(gauss84phiphi_30))
# Out:
# 0.9976198934588422

# %%
gauss84orth_30 = affscsp.L1normnumdirdersamplaffgausskernel(8, 4, math.pi/6, 0, 1, 32)
plt.imshow(gauss84orth_30, cmap='gray', interpolation='nearest')

# %%
np.sum(np.abs(gauss84orth_30))
# Out:
# 0.9935080212312164

# %%
gauss84orthorth_30 = affscsp.L1normnumdirdersamplaffgausskernel(8, 4, math.pi/6, 0, 2, 32)
plt.imshow(gauss84orthorth_30, cmap='gray', interpolation='nearest')

# %%
np.sum(np.abs(gauss84orthorth_30))
# Out:
# 0.9877975483987139

# %%
gauss84phiorth_30 = affscsp.L1normnumdirdersamplaffgausskernel(8, 4, math.pi/6, 1, 1, 32)
plt.imshow(gauss84phiorth_30, cmap='gray', interpolation='nearest')

# %%
np.sum(np.abs(gauss84orthorth_30))
# Out:
# 0.9877975483987139
